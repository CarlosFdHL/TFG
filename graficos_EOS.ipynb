# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import funcionesTFG as f
import importlib
from scipy.optimize import curve_fit
import matplotlib.ticker as ticker
from scipy.optimize import fsolve
from mpl_toolkits.mplot3d import Axes3D
from scipy import optimize

from matplotlib.ticker import ScalarFormatter

importlib.reload(f)
# Out:
# <module 'funcionesTFG' from '/home/carlosfdhl/work/py/funcionesTFG.py'>

# %% [markdown]
# <h1>CH</h1>

# %% [markdown]
# <h2>Hugoniot</h2>

# %%
ax = f.graf_Hugoniot('/home/carlosfdhl/work/hugoniot/M4CH_maxwell.txt')

#Datos experimentales
path_DatosExperimentales = 'DatosExperimentales.xlsx'

datos_experimentales = pd.read_excel(path_DatosExperimentales, sheet_name = 'Polystyrene')
columna = 'R0 (g/cm3)'
valor_referencia = 1.05
porcentaje = 0.01

datos_experimentales = f.filtrar_dataframe(datos_experimentales, columna, valor_referencia, porcentaje)

#Almacenar datos experimentales en vectores
p_exp = datos_experimentales["Pressure (GPa)"].to_numpy(dtype=float)
r_exp = datos_experimentales['R(g/cm3)'].to_numpy(dtype=float)
r_exp = [r*1000 for r in r_exp]

datos_fpeos = f.leer_fpeos()
p_fpeos=datos_fpeos["P (GPa)"].to_numpy(dtype=float)
r_fpeos=datos_fpeos['R (kg/m3)'].to_numpy(dtype=float)

#Concatenar vectores datos experimentales
r_exp , p_exp = f.concat_RP(r_exp, p_exp, r_fpeos, p_fpeos)
ax.scatter(r_exp, p_exp, color='red', s=20, marker = '^', edgecolor='red', facecolor='none', label=r'Datos Experimentales (GPa)')


datos = f.leer_hugoniot('/home/carlosfdhl/work/hugoniot/M4CH.txt')
Rho = datos["R (kg/m3)"].to_numpy(dtype=float)
T = datos["T (K)"].to_numpy(dtype=float)

#plt.savefig('img/Resultados/CH/CH_Hug.png', dpi=400)

# %% [markdown]
# <h2>Presión</h2>

# %%
fig = f.graf_P_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat' , cantidad =10, xlim=(1e-2,10**5), ylim=(10**(-3),10**7) )
fig.tight_layout()

#plt.savefig('img/Resultados/CH/CH_P.png', dpi=400)

# %% [markdown]
# <h2>Energía interna</h2>

# %%
fig = f.graf_e_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat' , cantidad =10, xlim=(1e-2,10**6), ylim=(10**(-1),10**4) )

fig.tight_layout()

#plt.savefig('img/Resultados/M0CH/M0CH_e.png', dpi=400)

# %% [markdown]
# <h2>Ionización</h2>

# %%
fig = f.graf_z_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat' , cantidad =10, xlim=(1e-2,10**6), ylim=(10**(-1),0.4*1e1) )
fig.tight_layout()

#plt.savefig('img/Resultados/CH/CH_z.png', dpi=400)

# %% [markdown]
# <h2>Cs</h2>

# %%
fig1, fig2 = f.graf_cs_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat' , cantidad =10, xlim=(1e-2,10**6), ylim=(5*10**(2),10**6) )

fig1.tight_layout()
fig2.tight_layout()
#fig1.savefig('img/Resultados/CH/CH_cs.png', dpi=400)
#fig2.savefig('img/Resultados/CH/CH_cs_cond.png', dpi=400)

# %% [markdown]
# <h2>Cv</h2>

# %%
fig1,fig2 = f.graf_cv_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat' , cantidad =10, xlim=(1,10**5), ylim=(10**(-1),10**6) )

fig1.tight_layout()
fig2.tight_layout()
#fig1.savefig('img/Resultados/CH/CH_cv.png', dpi=400)
#fig2.savefig('img/Resultados/CH/CH_cv_cond.png', dpi=400)
# Out:
# 0.00011604000000000001

# %% [markdown]
# <h2>Condiciones</h2>

# %%
fig1= f.graf_condiciones(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4CH.dat')
fig1.tight_layout()

fig1.savefig('img/Resultados/CH/CH_cond.png', dpi=400)

# %% [markdown]
# <h1>Au</h1>

# %% [markdown]
# <h2>Hugoniot</h2>

# %%
ax = f.graf_Hugoniot('/home/carlosfdhl/work/hugoniot/M0Au.txt')

#Datos experimentales
path_DatosExperimentales = 'DatosExperimentales.xlsx'

datos_experimentales = pd.read_excel(path_DatosExperimentales, sheet_name = 'Gold')
columna = 'R0 (g/cm3)'
valor_referencia = 19.3
porcentaje = 0.05

datos_experimentales = f.filtrar_dataframe(datos_experimentales, columna, valor_referencia, porcentaje)

#Almacenar datos experimentales en vectores
p_exp = datos_experimentales["Pressure (GPa)"].to_numpy(dtype=float)
r_exp = datos_experimentales['R(g/cm3)'].to_numpy(dtype=float)
r_exp = [r*1000 for r in r_exp]

ax.scatter(r_exp, p_exp, color='red', s=20, marker = '^', edgecolor='red', facecolor='none', label=r'Datos Experimentales (GPa)')
plt.savefig('img/Resultados/Au/Au_Hug.png', dpi=400)

# %% [markdown]
# <h2>Presión</h2>

# %%
fig = f.graf_P_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' , cantidad =10, xlim=(1,10**7), ylim=(10**(-1),10**8) )
fig.tight_layout()

plt.savefig('img/Resultados/Au/Au_P.png', dpi=400)

# %% [markdown]
# <h2>Energía interna</h2>

# %%
fig = f.graf_e_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' , cantidad =10, xlim=(1,10**7), ylim=(10**(-1),10**6) )
fig.tight_layout()

plt.savefig('img/Resultados/Au/Au_e.png', dpi=400)

# %% [markdown]
# <h2>Ionización</h2>

# %%
fig = f.graf_z_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' , cantidad =10, xlim=(1,10**7), ylim=(10**(-1),70) )
fig.tight_layout()

plt.savefig('img/Resultados/Au/Au_z.png', dpi=400)

# %% [markdown]
# <h2>Cs</h2>

# %%
fig1, fig2 = f.graf_cs_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' , cantidad =10, xlim=(1,10**7), ylim=(10**(1),10**6) )
fig1.tight_layout()
fig2.tight_layout()
fig1.savefig('img/Resultados/Au/Au_cs.png', dpi=400)
fig2.savefig('img/Resultados/Au/Au_cs_cond.png', dpi=400)

# %% [markdown]
# <h2>Cv</h2>

# %%
fig1, fig2 = f.graf_cv_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' , cantidad =10, xlim=(1,10**7), ylim=(10**(-1),10**6) )
fig1.tight_layout()
fig2.tight_layout()
fig1.savefig('img/Resultados/Au/Au_cv.png', dpi=400)
fig2.savefig('img/Resultados/Au/Au_cv_cond.png', dpi=400)
# Out:
# 0.00011604000000000001

# %% [markdown]
# <h2>Condiciones</h2>

# %%
fig1 = f.graf_condiciones(path ='/home/carlosfdhl/work/hugoniot/eosTable/M0Au.dat' )
fig1.tight_layout()

fig1.savefig('img/Resultados/Au/Au_cond.png', dpi=400)

# %% [markdown]
# <h1>DT</h1>

# %% [markdown]
# <h2>Hugoniot</h2>

# %%
ax = f.graf_Hugoniot('/home/carlosfdhl/work/hugoniot/M4DT_maxwell.txt')

#Datos experimentales
path_DatosExperimentales = 'DatosExperimentales.xlsx'

datos_experimentales = pd.read_excel(path_DatosExperimentales, sheet_name = 'Deuterium')
columna = 'R0 (g/cm3)'
valor_referencia = 0.17
porcentaje = 0.05

datos_experimentales = f.filtrar_dataframe(datos_experimentales, columna, valor_referencia, porcentaje)

#Almacenar datos experimentales en vectores
p_exp = datos_experimentales["Pressure (GPa)"].to_numpy(dtype=float)
r_exp = datos_experimentales['R(g/cm3)'].to_numpy(dtype=float)
r_exp = [r*1000 for r in r_exp]

ax.scatter(r_exp, p_exp, color='red', s=20, marker = '^', edgecolor='red', facecolor='none', label=r'Datos Experimentales (GPa)')
#plt.savefig('img/Resultados/M0DT/M0DT_Hug.png', dpi=400)

# %% [markdown]
# <h2>Presión</h2>

# %%
fig = f.graf_P_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat' , cantidad =10, xlim=(1,10**5), ylim=(10**(-1),10**7) )
fig.tight_layout()

#plt.savefig('img/Resultados/M0DT/M0DT_P.png', dpi=400)

# %% [markdown]
# <h2>Energía interna</h2>

# %%
fig = f.graf_e_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat' , cantidad =10, xlim=(1,10**5), ylim=(10**(-1),10**6) )
fig.tight_layout()

#plt.savefig('img/Resultados/M0DT/M0DT_e.png', dpi=400)

# %% [markdown]
# <h2>Ionización</h2>

# %%
fig = f.graf_z_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat' , cantidad =10, xlim=(1,10**5), ylim=(0,1.25) )
fig.tight_layout()

#plt.savefig('img/Resultados/M0DT/M0DT_z.png', dpi=400)

# %% [markdown]
# <h2>Cs</h2>

# %%
fig1,fig2 = f.graf_cs_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat' , cantidad =10, xlim=(1,10**5), ylim=(10**(3),10**6) )
fig1.tight_layout()
fig2.tight_layout()
#fig1.savefig('img/Resultados/M0DT/M0DT_cs.png', dpi=400)
#fig2.savefig('img/Resultados/M0DT/M0DT_cs_cond.png', dpi=400)

# %% [markdown]
# <h2>Cv</h2>

# %%
fig1,fig2 = f.graf_cv_RT_EOSTABLE(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat' , cantidad =10, xlim=(1,10**5), ylim=(10**(3),10**6) )
fig1.tight_layout()
fig2.tight_layout()
#fig1.savefig('img/Resultados/M0DT/M0DT_cv.png', dpi=400)
#fig2.savefig('img/Resultados/M0DT/M0DT_cv_cond.png', dpi=400)
# Out:
# 116.04

# %% [markdown]
# <h2>Condiciones</h2>

# %%
fig1 = f.graf_condiciones(path ='/home/carlosfdhl/work/hugoniot/eosTable/M4DT_maxwell.dat')
fig1.tight_layout()

#fig1.savefig('img/Resultados/M0DT/M0DT_cond.png', dpi=400)
